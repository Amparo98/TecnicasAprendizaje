# %% [markdown]
# # Clustering

# %% [markdown]
# ### Introducción
# ---

# %% [markdown]
# Usando conjuntos de datos con información sobre el tráfico en diferentes carreteras de
# Gipuzkoa, encuentra patrones que permitan perfilar las distribuciones de tráfico por hora
# y zona. Puedes utilizar cualquier técnica de clustering, pero deberás justificar su elección
# e interpretar los resultados acorde a ella.

# %% [markdown]
# ### Importar librerías necesarias

# %% [markdown]
# Se prodecera a importar las librerías necesarias para un posterior funcionamiento

# %% [markdown]
# #### Manipulación y Procesamiento de Datos

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Visualización de Datos

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Modelado y evaluacion de Modelos

# %%
from sklearn.cluster import DBSCAN, KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# %% [markdown]
# ### Carga de Datos
